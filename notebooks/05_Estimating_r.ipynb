# %%
# Setup and Data Loading


# Core libraries
# Data utilities
from functools import partial

import healpy as hp

# JAX ecosystem
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import scienceplots  # noqa: F401
from furax import HomothetyOperator
from furax.obs import negative_log_likelihood, sky_signal
from furax.obs.stokes import Stokes
from furax_cs.data import (
    get_mask,
    load_cmb_map,
    load_fg_map,
    load_from_cache,
    save_cmb_map,
    save_to_cache,
)
from furax_cs.optim import minimize

# JAX-HEALPix for clustering and sky operations
from jax_healpy.clustering import (
    find_kmeans_clusters,
    get_cutout_from_mask,
    get_fullmap_from_cutout,
    normalize_by_first_occurrence,
)
# Out:
# W0114 09:32:37.301969   40413 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0114 09:32:37.308490   40199 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.

# %%
# Configure JAX
jax.config.update("jax_enable_x64", True)

r_tensor_to_scaler_ratio = 2
# Load CMB and foreground data
nside = 64
npixels = 12 * nside**2
noise_id = 0
noise_ratio = 1.0
tag = f"cr{r_tensor_to_scaler_ratio}d0s0"
mask_name = "ALL"

# %%
# Generate and load multi-frequency data
save_to_cache(nside, sky=tag)
save_cmb_map(nside, sky=tag)
nu, freq_maps = load_from_cache(nside, sky=tag)
_, fg_maps = load_fg_map(nside, sky=tag)
cmb_map = load_cmb_map(nside, sky=tag)

print(f"Frequency maps shape: {freq_maps.shape}")
print(f"Frequencies: {len(nu)} bands from {nu[0]:.0f} to {nu[-1]:.0f} GHz")

# Convert to FURAX format (Q,U polarization)
d = Stokes.from_stokes(Q=freq_maps[:, 1, :], U=freq_maps[:, 2, :])
fg_stokes = Stokes.from_stokes(fg_maps[:, 1], fg_maps[:, 2])
cmb_map_stokes = Stokes.from_stokes(cmb_map[1], cmb_map[2])

# Load galactic mask (cleanest 20% of sky)
mask = get_mask(mask_name, nside=nside)
(indices,) = jnp.where(mask == 1)
coverage = jnp.mean(mask) * 100
print(f"Sky coverage: {coverage:.1f}% ({len(indices):,} pixels)")

# Extract masked data for computation
masked_d = get_cutout_from_mask(d, indices, axis=1)
masked_fg = get_cutout_from_mask(fg_stokes, indices, axis=1)
masked_cmb = get_cutout_from_mask(cmb_map_stokes, indices)
print(f"Masked data shape: {masked_d.shape}")
# Out:
# [INFO] Loaded freq_maps for nside 64 from cache with noise_ratio 0.0.
# [INFO] Generating CMB map for nside 64, sky cr2d0s0
# [INFO] generating with r_value 0.002
# ✓ Generated and saved freq_maps for nside 64 and for tag cr2.
# [INFO] Loaded freq_maps for nside 64 from cache.
# [INFO] Loaded freq_maps for nside 64 from cache.
# [INFO] Loaded freq_maps for nside 64 from cache.
# Frequency maps shape: (15, 3, 49152)
# Frequencies: 15 bands from 40 to 402 GHz
# Sky coverage: 100.0% (49,152 pixels)
# Masked data shape: (15, 49152)

# %%
# Spherical K-means Clustering
# Configure clustering parameters for different spectral indices
cluster_config = {
    "temp_dust": 30000,  # Dust temperature clusters
    "beta_dust": 1500,  # Dust spectral index clusters
    "beta_pl": 1500,  # Synchrotron spectral index clusters
}
cluster_config = jax.tree.map(lambda x: min(indices.size, x), cluster_config)

# Generate clusters for each parameter type
print("Generating spherical K-means clusters...")
clusters = {}

# Generate spherical K-means clusters on unmasked pixels
cluster_map = jax.tree.map(
    lambda c: find_kmeans_clusters(
        mask,
        indices,
        c,
        jax.random.PRNGKey(42),  # Fixed seed for reproducibility
        max_centroids=c,
        initial_sample_size=1,
    ),
    cluster_config,
)

cluster_map = jax.tree.map(
    lambda arr, c: normalize_by_first_occurrence(arr, c, c), cluster_map, cluster_config
)

cluster_map = {f"{param}_patches": patches for param, patches in cluster_map.items()}

print("Clustering complete!")

# Visualize the clustering results
fig = plt.figure(figsize=(15, 5))

param_labels = ["Dust Temperature", "Dust Spectral Index", "Synchrotron Index"]
for i, (param, label) in enumerate(zip(cluster_config.keys(), param_labels)):
    cluster_data = cluster_map[f"{param}_patches"]
    n_unique = jnp.unique(cluster_data[cluster_data != hp.UNSEEN]).size

    hp.mollview(
        cluster_data,
        title=f"{label}\n({n_unique} clusters)",
        sub=(1, 3, i + 1),
        bgcolor=(0.0,) * 4,
    )

plt.tight_layout()
plt.show()

# Extract masked clusters for optimization
masked_clusters = get_cutout_from_mask(cluster_map, indices)
masked_clusters = jax.tree.map(lambda x: x.astype(jnp.int64), masked_clusters)
print("Masked clusters ready for optimization")
# Out:
# Generating spherical K-means clusters...
# Clustering complete!
# /tmp/ipykernel_27890/3647255614.py:50: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Masked clusters ready for optimization

# %%
# Parameter Optimization

# Setup optimization parameters
dust_nu0 = 160.0  # Dust reference frequency (GHz)
synchrotron_nu0 = 20.0  # Synchrotron reference frequency (GHz)

# Create objective function with fixed reference frequencies
negative_log_likelihood_fn = partial(
    negative_log_likelihood,
    dust_nu0=dust_nu0,
    synchrotron_nu0=synchrotron_nu0,
    analytical_gradient=True,
)

sky_signal_fn = partial(sky_signal, dust_nu0=dust_nu0, synchrotron_nu0=synchrotron_nu0)

# Initialize parameters for each resolution level (realistic starting values)
base_params = {
    "beta_dust": 1.54,  # Dust spectral index
    "temp_dust": 20.0,  # 20K dust temperature
    "beta_pl": -3.0,  # Synchrotron index
}
initial_params = jax.tree.map(lambda v, c: jnp.full((c,), v), base_params, cluster_config)

print("Parameter initialization:")
for param, values in initial_params.items():
    print(f"  {param}: {len(values)} patches at resolution, initial value = {values[0]}")

# Create noise operator (simplified for demonstration)
N = HomothetyOperator(jnp.ones(1), _in_structure=masked_d.structure)
# Out:
# Parameter initialization:
#   beta_dust: 500 patches at resolution, initial value = 1.54
#   beta_pl: 500 patches at resolution, initial value = -3.0
#   temp_dust: 500 patches at resolution, initial value = 20.0

# %%
print("\nRunning multi-resolution optimization...")
print("This may take a few minutes...")
# Run optimization using unified minimize API
final_params, final_state = minimize(
    fn=negative_log_likelihood_fn,
    init_params=initial_params,
    solver_name="optax_lbfgs_zoom",
    max_iter=1000,
    rtol=1e-10,
    atol=1e-8,
    nu=nu,
    N=N,
    d=masked_d,
    patch_indices=masked_clusters,
)

# Show optimization results
print("\nOptimization completed!")
print(f"Final function value: {final_state.state.best_loss:.2e}")
# Out:
# Running multi-resolution optimization...
# This may take a few minutes...
# 100.00%|██████████| [00:02<00:00, 39.11%/s]
# Optimization completed!
# Final function value: -1.27e+10

# %%
# Compute CMB reconstruction with optimized parameters
reconstructed_signal = sky_signal_fn(
    final_params, nu=nu, d=masked_d, N=N, patch_indices=masked_clusters
)
cmb_reconstruction_masked = reconstructed_signal["cmb"]
cmb_reconstruction = jax.tree.map(
    lambda x: get_fullmap_from_cutout(x, indices, nside), cmb_reconstruction_masked
)
print("\nCMB reconstruction completed")
print(f"CMB shape: Q={cmb_reconstruction.q.shape}, U={cmb_reconstruction.u.shape}")
# Out:
# CMB reconstruction completed
# CMB shape: Q=(49152,), U=(49152,)

# %%
fig = plt.figure(figsize=(15, 7))

hp.mollview(
    cmb_reconstruction.q,
    title="CMB Reconstruction - Q Stokes Parameter",
    sub=(2, 3, 1),
    bgcolor=(0.0,) * 4,
)
hp.mollview(
    cmb_map[1],
    title="CMB Original - Q Stokes Parameter",
    sub=(2, 3, 2),
    bgcolor=(0.0,) * 4,
)
hp.mollview(
    cmb_reconstruction.q - cmb_map[1],
    title="CMB Reconstruction Error - Q Stokes Parameter",
    cmap="RdBu_r",
    sub=(2, 3, 3),
    bgcolor=(0.0,) * 4,
)
hp.mollview(
    cmb_reconstruction.u,
    title="CMB Reconstruction - U Stokes Parameter",
    sub=(2, 3, 4),
    bgcolor=(0.0,) * 4,
)
hp.mollview(
    cmb_map[2],
    title="CMB Original - U Stokes Parameter",
    sub=(2, 3, 5),
    bgcolor=(0.0,) * 4,
)
hp.mollview(
    cmb_reconstruction.u - cmb_map[2],
    title="CMB Reconstruction Error - U Stokes Parameter",
    cmap="RdBu_r",
    sub=(2, 3, 6),
    bgcolor=(0.0,) * 4,
)

# %%
print("\nRunning multi-resolution optimization...")
print("This may take a few minutes...")
# Run optimization using unified minimize API
wd_finale_params, wd_finale_state = minimize(
    fn=negative_log_likelihood_fn,
    init_params=initial_params,
    solver_name="optax_lbfgs_zoom",
    max_iter=1000,
    rtol=1e-10,
    atol=1e-8,
    nu=nu,
    N=N,
    d=masked_fg,
    patch_indices=masked_clusters,
)

# Compute CMB reconstruction with optimized parameters
reconstructed_wd_signal = sky_signal_fn(
    wd_finale_params, nu=nu, d=masked_fg, N=N, patch_indices=masked_clusters
)
cmb_syst_masked = reconstructed_wd_signal["cmb"]
cmb_syst = jax.tree.map(lambda x: get_fullmap_from_cutout(x, indices, nside), cmb_syst_masked)
cmb_syst_np = jnp.stack([cmb_syst.q, cmb_syst.u], axis=0)

# Show optimization results
print("\nOptimization completed!")
print(f"Final function value: {final_state.state.best_loss:.2e}")
# Out:
# Running multi-resolution optimization...
# This may take a few minutes...
# 100.00%|██████████| [00:02<00:00, 48.88%/s]
# Optimization completed!
# Final function value: -1.27e+10

# %%
from furax_cs.r_analysis import estimate_r_from_maps, plot_r_estimator

cmb_reconstruction_np = jnp.stack([cmb_reconstruction.q, cmb_reconstruction.u], axis=0)
r_best, sigma_r_neg, sigma_r_pos, r_grid, L_vals, ell_range, cl_bb_r1, _, _ = estimate_r_from_maps(
    cmb_map, cmb_reconstruction_np, cmb_syst_np
)

plot_r_estimator("R = 00.3", r_best, sigma_r_neg, sigma_r_pos, r_grid, L_vals, output_format="show")
# Out:
# [INFO] Mask detected: False, f_sky = 1.000, is_cl_obs = True
# cmb_hat shape: (2, 49152)
# shape of cmb_hat_expanded: (2, 49152) and cmb_expanded: (3, 49152)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:220, in _broadcast_shapes_uncached(*shapes)
#     219 try:
# --> 220   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     221 except TypeError as err:
#     222   # Raise ValueError here for backward compatibility.
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:135, in _try_broadcast_shapes(name, *shapes)
#     134     else:
# --> 135       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     136                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     137 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 2, 49152), (1, 3, 49152).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/util.py:300, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     299   return f(*args, **kwargs)
# --> 300 return cached(trace_context(), *args, **kwargs)
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/util.py:294, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     292 @functools.lru_cache(max_size)
#     293 def cached(_, *args, **kwargs):
# --> 294   return f(*args, **kwargs)
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:204, in _broadcast_shapes_cached(*shapes)
#     202 @cache()
#     203 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 204   return _broadcast_shapes_uncached(*shapes)
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:223, in _broadcast_shapes_uncached(*shapes)
#     221 except TypeError as err:
#     222   # Raise ValueError here for backward compatibility.
# --> 223   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(2, 49152), (1, 3, 49152)]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:135, in _try_broadcast_shapes(name, *shapes)
#     134     else:
# --> 135       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     136                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     137 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 2, 49152), (1, 3, 49152).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       1 cmb_reconstruction_np = jnp.stack(
#       2     [cmb_reconstruction.q, cmb_reconstruction.u], axis=0
#       3 )
# ----> 4 r_best , sigma_r_neg, sigma_r_pos , r_grid , L_vals , ell_range, cl_bb_r1, _ , _ = estimate_r_from_maps(cmb_map ,   cmb_reconstruction_np , cmb_syst_np)
#
# Cell In[29], line 208, in estimate_r_from_maps(cmb, cmb_hat, syst_map, nside, max_point)
#     204 if cmb_hat_expanded is not None and syst_map_expanded is not None:
#     205     # Compute spectra directly (compatible with both masked and unmasked)
#     206     # Statistical residuals
#     207     print(f"shape of cmb_hat_expanded: {cmb_hat_expanded.shape} and cmb_expanded: {cmb_expanded.shape}")
# --> 208     res = cmb_hat_expanded - cmb_expanded[np.newaxis, ...]
#     209     res_stat = res - syst_map_expanded[np.newaxis, ...]
#     211     cl_list = []
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:608, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     606 args = (other, self) if swap else (self, other)
#     607 if isinstance(other, _accepted_binop_types):
# --> 608   return binary_op(*args)
#     609 # Note: don't use isinstance here, because we don't want to raise for
#     610 # subclasses, e.g. NamedTuple objects that may override operators.
#     611 if type(other) in _rejected_binop_types:
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/numpy/ufunc_api.py:182, in ufunc.__call__(self, out, where, *args)
#     180   raise NotImplementedError(f"where argument of {self}")
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/numpy/ufuncs.py:1569, in subtract(x, y)
#    1542 @binary_ufunc(identity=None, at=_subtract_at)
#    1543 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1544   """Subtract two arrays element-wise.
#    1545
#    1546   JAX implementation of :obj:`numpy.subtract`. This is a universal function,
#    (...)   1567     Array([-10,  -9,  -8,  -7], dtype=int32)
#    1568   """
# -> 1569   out = lax.sub(*promote_args("subtract", x, y))
#    1570   jnp_error._set_error_if_nan(out)
#    1571   return out
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/numpy/util.py:229, in promote_args(fun_name, *args)
#     227 _check_no_float0s(fun_name, *args)
#     228 check_for_prngkeys(fun_name, *args)
# --> 229 return promote_shapes(fun_name, *promote_dtypes(*args))
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/numpy/util.py:67, in promote_shapes(fun_name, *args)
#      65 if config.numpy_rank_promotion.value != "allow":
#      66   _rank_promotion_warning_or_error(fun_name, shapes)
# ---> 67 result_rank = len(lax.broadcast_shapes(*shapes))
#      68 return [lax.broadcast_to_rank(arg, result_rank) for arg in args]
#
#     [... skipping hidden 1 frame]
#
# File ~/micromamba/envs/fg/lib/python3.11/site-packages/jax/_src/lax/lax.py:223, in _broadcast_shapes_uncached(*shapes)
#     220   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     221 except TypeError as err:
#     222   # Raise ValueError here for backward compatibility.
# --> 223   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(2, 49152), (1, 3, 49152)]
