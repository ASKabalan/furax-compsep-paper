# %%
import os

from jax_hpc_profiler import plot_weak_scaling

out_folder = "plots"
os.makedirs(out_folder, exist_ok=True)

# %%
csv_file = ["../results/runs/CLUSTERS_FURAX.csv"]
label_text = "%f%"

plot_weak_scaling(
    csv_files=csv_file,
    figure_size=(8, 6),
    precisions=["float64"],
    label_text=label_text,
    xlabel="Number of Patches",
    title="Runtime Comparison",
    output=f"{out_folder}/runtime_comparison.pdf",
)
# Out:
# requested GPUS: None available GPUS: {1}
# requested data sizes: None available data sizes: {100, 200, 1000, 10, 50, 20, 500}
